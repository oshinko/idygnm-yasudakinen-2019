# %%
import pandas as pd
import pathlib
from sklearn.neighbors import KNeighborsClassifier

# 学習データ読み込み
train = pd.read_csv('data.csv')
train.shape
# Out:
# (3444, 17)

# %%
# 予測対象読み込み
target = pd.read_csv('yasuda-kinen-2019.csv')
target
# Out:
#           date  race weather  horses condition  fam  gate  number       name  \
# 0   2019-06-02  安田記念       晴      16         良    0     1       1  ケイアイノーテック
# 1   2019-06-02  安田記念       晴      16         良    0     1       2     アエロリット
# 2   2019-06-02  安田記念       晴      16         良    0     2       3  サクラアンプルール
# 3   2019-06-02  安田記念       晴      16         良    0     2       4    サングレーザー
# 4   2019-06-02  安田記念       晴      16         良    0     3       5   インディチャンプ
# 5   2019-06-02  安田記念       晴      16         良    0     3       6    グァンチャーレ
# 6   2019-06-02  安田記念       晴      16         良    0     4       7    モズアスコット
# 7   2019-06-02  安田記念       晴      16         良    0     4       8     ステルヴィオ
# 8   2019-06-02  安田記念       晴      16         良    0     5       9  スマートオーディン
# 9   2019-06-02  安田記念       晴      16         良    0     5      10  フィアーノロマーノ
# 10  2019-06-02  安田記念       晴      16         良    0     6      11   エントシャイデン
# 11  2019-06-02  安田記念       晴      16         良    0     6      12    ロードクエスト
# 12  2019-06-02  安田記念       晴      16         良    0     7      13   ペルシアンナイト
# 13  2019-06-02  安田記念       晴      16         良    0     7      14    アーモンドアイ
# 14  2019-06-02  安田記念       晴      16         良    0     8      15   ダノンプレミアム
# 15  2019-06-02  安田記念       晴      16         良    0     8      16      ロジクライ
#
#    sex  age  weight   odds  popular  weight_diff training_center
# 0    牡    4      58   55.3       11            0               西
# 1    牝    5      56   13.5        3            0               東
# 2    牡    8      58  138.7       15            0               西
# 3    牡    5      58   27.1        6            0               西
# 4    牡    4      58   21.6        5            0               西
# 5    牡    7      58   77.7       13            0               西
# 6    牡    5      58   30.5        7            0               西
# 7    牡    4      58   20.6        4            0               東
# 8    牡    6      58   61.6       12            0               西
# 9    牡    5      58   33.9        9            0               西
# 10   牡    4      58  123.8       14            0               西
# 11   牡    6      58  191.6       16            0               東
# 12   牡    5      58   31.6        8            0               東
# 13   牝    4      56    1.6        1            0               東
# 14   牡    4      58    3.9        2            0               西
# 15   牡    6      58   51.1       10            0               西

# %%
def divide(df):
    """ラベル分割.
    """
    df = df.copy()
    df.drop(['date', 'race', 'name'], axis=1, inplace=True)
    weather_index = {x: i for i, x in enumerate(['晴', '曇', '小雨', '雨'])}
    df['weather'] = df.weather.map(lambda x: weather_index[x])
    condition_index = {x: i for i, x in enumerate(['良', '稍', '重', '不'])}
    df['condition'] = df.condition.map(lambda x: condition_index[x])
    df['fam'] = df.fam.map(int)
    sex_index = {x: i for i, x in enumerate(['牡', '牝', 'セ'])}
    df['sex'] = df.sex.map(lambda x: sex_index[x])
    training_center_index = {x: i for i, x in enumerate(['東', '西', '外', '地', '他'])}
    df['training_center'] = df.training_center.map(lambda x: training_center_index[x])
    if 'result' in df:
        df = df[df.result.astype(str).str.isdigit()]
        df['result'] = df.result.astype(int)
    df = df.dropna()
    return (df[[x for x in df.columns if not x == 'result']].values,
            df.result.map(lambda x: 1 if x <= 3 else 0).values if 'result' in df else None)

# %%
# 学習データをラベル分割
X, y = divide(train)
X.shape, y.shape
# Out:
# ((3379, 13), (3379,))

# %%
# 予測対象をラベル分割
X_pred, _ = divide(target)
X_pred.shape
# Out:
# (16, 13)

# %%
# 現ナマを召喚
knc = KNeighborsClassifier(n_neighbors=1)  # k は適当
knc.fit(X, y)

# 予測
y_pred = knc.predict(X_pred)

# 結果
target.assign(pred=y_pred)
# Out:
#           date  race weather  horses condition  fam  gate  number       name  \
# 0   2019-06-02  安田記念       晴      16         良    0     1       1  ケイアイノーテック
# 1   2019-06-02  安田記念       晴      16         良    0     1       2     アエロリット
# 2   2019-06-02  安田記念       晴      16         良    0     2       3  サクラアンプルール
# 3   2019-06-02  安田記念       晴      16         良    0     2       4    サングレーザー
# 4   2019-06-02  安田記念       晴      16         良    0     3       5   インディチャンプ
# 5   2019-06-02  安田記念       晴      16         良    0     3       6    グァンチャーレ
# 6   2019-06-02  安田記念       晴      16         良    0     4       7    モズアスコット
# 7   2019-06-02  安田記念       晴      16         良    0     4       8     ステルヴィオ
# 8   2019-06-02  安田記念       晴      16         良    0     5       9  スマートオーディン
# 9   2019-06-02  安田記念       晴      16         良    0     5      10  フィアーノロマーノ
# 10  2019-06-02  安田記念       晴      16         良    0     6      11   エントシャイデン
# 11  2019-06-02  安田記念       晴      16         良    0     6      12    ロードクエスト
# 12  2019-06-02  安田記念       晴      16         良    0     7      13   ペルシアンナイト
# 13  2019-06-02  安田記念       晴      16         良    0     7      14    アーモンドアイ
# 14  2019-06-02  安田記念       晴      16         良    0     8      15   ダノンプレミアム
# 15  2019-06-02  安田記念       晴      16         良    0     8      16      ロジクライ
#
#    sex  age  weight   odds  popular  weight_diff training_center  pred
# 0    牡    4      58   55.3       11            0               西     0
# 1    牝    5      56   13.5        3            0               東     1
# 2    牡    8      58  138.7       15            0               西     0
# 3    牡    5      58   27.1        6            0               西     1
# 4    牡    4      58   21.6        5            0               西     0
# 5    牡    7      58   77.7       13            0               西     0
# 6    牡    5      58   30.5        7            0               西     0
# 7    牡    4      58   20.6        4            0               東     1
# 8    牡    6      58   61.6       12            0               西     0
# 9    牡    5      58   33.9        9            0               西     0
# 10   牡    4      58  123.8       14            0               西     1
# 11   牡    6      58  191.6       16            0               東     0
# 12   牡    5      58   31.6        8            0               東     0
# 13   牝    4      56    1.6        1            0               東     1
# 14   牡    4      58    3.9        2            0               西     0
# 15   牡    6      58   51.1       10            0               西     0
